# %% [markdown]
# <a href="https://colab.research.google.com/github/aruna-neela/Hotel-Booking-Analysis/blob/main/Hotel_Booking_Analysis_Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Hotel Booking Analysis
# Exploratory Data Analysis

# %% [markdown]
# ##### **Project Type**    - Classification
# ##### **Contribution**    - Individual
# #### **Team Member 1**   - Neela.Aruna

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The hotel booking dataset offers a treasure trove of insights for understanding booking dynamics and optimizing revenue strategies. Through exploratory data analysis, key trends such as seasonal booking patterns and optimal stay durations can be uncovered. By identifying peak seasons and common lengths of stay, hotels can adjust pricing strategies to maximize occupancy rates and revenue. Additionally, analyzing guest demographics and preferences, including special requests and amenities, enables hotels to personalize the guest experience and enhance satisfaction. Leveraging these insights allows hotels to stay competitive in the market by offering tailored services and optimizing resource allocation.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/aruna-neela/Hotel-Booking-Analysis/blob/main/Hotel_Booking_Analysis_Exploratory_Data_Analysis.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This project aims to conduct exploratory data analysis on a hotel booking dataset to uncover insights for revenue optimization and guest satisfaction. It will focus on identifying seasonal booking patterns, analyzing stay durations, understanding guest demographics, investigating special requests, and exploring the relationship between amenities and booking patterns. By addressing these objectives, the project seeks to provide actionable insights to help hotels make data-driven decisions for maximizing revenue and enhancing the guest experience.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective of this project is to leverage exploratory data analysis (EDA) on the hotel booking dataset to inform strategic decision-making for hotels. This includes optimizing revenue management strategies, enhancing guest satisfaction, and improving operational efficiency. By uncovering insights into seasonal booking patterns, stay durations, guest demographics, special requests, and amenities utilization, the project aims to provide actionable recommendations that enable hotels to:
#
# 1. Maximize revenue by adjusting pricing strategies based on demand fluctuations and guest preferences.
# 2. Enhance guest satisfaction by personalizing the guest experience and anticipating their needs.
# 3. Improve operational efficiency by optimizing resource allocation and inventory management.
# 4. Stay competitive in the market by offering tailored services and amenities that cater to guest preferences.
#
# Overall, the business objective is to empower hotels with data-driven insights that drive revenue growth, improve guest loyalty, and establish a competitive edge in the hospitality industry.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
# Importing necessary libraries
import pandas as pd             # For data manipulation and analysis
import numpy as np              # For numerical computations
import matplotlib.pyplot as plt # For data visualization
import seaborn as sns           # For enhanced data visualization

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
# Importing necessary libraries
import pandas as pd             # For data manipulation and analysis

# Load dataset
df = pd.read_csv("/content/Hotel Bookings (1).csv")

# Display the first few rows of the dataset to understand its structure
print(df.head())
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
# Display basic information about the dataset
print("Dataset Info:")
print(df.info())

# Display the dimensions of the dataset (rows, columns)
print("\nDataset Dimensions:")
print(df.shape)

# Display the first few rows of the dataset
print("\nFirst Few Rows of the Dataset:")
print(df.head())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43917 entries, 0 to 43916
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           43917 non-null  object
#  1   is_canceled                     43917 non-null  int64
#  2   lead_time                       43917 non-null  int64
#  3   arrival_date_year               43917 non-null  int64
#  4   arrival_date_month              43917 non-null  object
#  5   arrival_date_week_number        43917 non-null  int64
#  6   arrival_date_day_of_month       43917 non-null  int64
#  7   stays_in_weekend_nights         43917 non-null  int64
#  8   stays_in_week_nights            43917 non-null  int64
#  9   adults                          43917 non-null  int64
#  10  children                        43913 non-null  float64
#  11  babies                          43917 non-null  int64
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
# Display the number of rows and columns in the dataset
print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])
# Out:
# Number of Rows: 43917
# Number of Columns: 32

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
# Display detailed information about the dataset
print("Dataset Info:")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43917 entries, 0 to 43916
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           43917 non-null  object
#  1   is_canceled                     43917 non-null  int64
#  2   lead_time                       43917 non-null  int64
#  3   arrival_date_year               43917 non-null  int64
#  4   arrival_date_month              43917 non-null  object
#  5   arrival_date_week_number        43917 non-null  int64
#  6   arrival_date_day_of_month       43917 non-null  int64
#  7   stays_in_weekend_nights         43917 non-null  int64
#  8   stays_in_week_nights            43917 non-null  int64
#  9   adults                          43917 non-null  int64
#  10  children                        43913 non-null  float64
#  11  babies                          43917 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
# Count duplicate rows in the dataset
duplicate_count = df.duplicated().sum()
print("Duplicate Rows Count:", duplicate_count)
# Out:
# Duplicate Rows Count: 7767

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# Count missing values (null values) in each column
missing_values_count = df.isnull().sum()
print("Missing Values Count:")
print(missing_values_count)
# Out:
# Missing Values Count:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             464
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       1
# deposit_type                          1
# ...

# %%
# Visualizing the missing values
import seaborn as sns
import matplotlib.pyplot as plt

# Create a heatmap of missing values
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cmap='viridis', cbar=False)
plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains information on hotel bookings, including booking dates, length of stay, guest demographics, and special requests. It includes data for both a city hotel and a resort hotel. There are missing values present in some columns, which may require handling. Exploratory data analysis will uncover insights into booking patterns and guest preferences to inform revenue management strategies and enhance the guest experience.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
# Display the columns of the dataset
print("Dataset Columns:")
print(df.columns)
# Out:
# Dataset Columns:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
# Display descriptive statistics for numerical columns
print("Dataset Describe:")
print(df.describe())
# Out:
# Dataset Describe:
#         is_canceled     lead_time  arrival_date_year  \
# count  96466.000000  96466.000000       96465.000000
# mean       0.458224    106.503100        2016.033204
# std        0.498254    108.267621           0.698661
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     18.000000        2016.000000
# 50%        0.000000     72.000000        2016.000000
# 75%        1.000000    164.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              96465.000000               96465.000000
# mean                  27.201420                  15.792661
# std                   13.438846                   8.777307
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset comprises hotel booking information, including booking details, guest demographics, and reservation status. Key variables include hotel type, booking cancellation status, lead time, guest counts, and booking channel. Additional features cover booking changes, deposit types, and special requests. Understanding these variables aids in analyzing booking patterns and guest behavior for strategic decision-making.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
# Iterate through each column and display unique values
for column in df.columns:
    unique_values = df[column].unique()
    print(f"Unique values for {column}: {unique_values}")
# Out:
# Unique values for hotel: ['Resort Hotel', 'City Hotel']
# Categories (2, object): ['City Hotel', 'Resort Hotel']
# Unique values for is_canceled: [0 1]
# Unique values for lead_time: [  6  24  33  34  27  35  36  28  17  37   0  38  30  32  40  41  21   3
#    2  15   7 364 114   5  18  12  11  23  31  39  14  19  25   1   8  10
#    4   9 154  70 228 222 151]
# Unique values for arrival_date_year: [2015 2016 2017]
# Unique values for arrival_date_month: ['October' 'November' 'May' 'June' 'December' 'January' 'March' 'February'
#  'April' 'July' 'August' 'September']
# Unique values for arrival_date_week_number: [42 44 45 46 20 25 50  5 21  9 49  2 19  8 12 15 28 36 37 52  1  4 10 23
#  24 32 33 39]
# Unique values for arrival_date_day_of_month: [11 26  3  4  5  6  7  8  9 12 13 19 30 29 16  2 10  1 14 15 28 21 23 24
#  31 20]
# Unique values for stays_in_weekend_nights: [2 7 0 3 4 1 9 5]
# Unique values for stays_in_week_nights: [ 0 15  3 10  9  8  7  6  5  4  2  1 21]
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/Hotel Bookings (1).csv')

# Display the first few rows of the dataset
print("Original Dataset:")
print(df.head())

# Check for missing values before dropping them
print("Missing values before dropping:")
print(df.isnull().sum())

# Drop rows with missing values
df.dropna(inplace=True)

# Check for missing values after dropping rows
print("Missing values after dropping:")
print(df.isnull().sum())

# Convert categorical variables to appropriate data types
categorical_cols = ['hotel', 'meal', 'country', 'market_segment', 'distribution_channel', 'reserved_room_type', 'assigned_room_type', 'deposit_type', 'customer_type', 'reservation_status']
for col in categorical_cols:
    if col in df.columns:
        df[col] = df[col].astype('category')

# Convert date columns to datetime data type
date_cols = ['reservation_status_date']
for col in date_cols:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col])

# Drop irrelevant columns
irrelevant_cols = ['agent', 'company']
df.drop(columns=irrelevant_cols, inplace=True, errors='ignore')

# Remove duplicate rows
df.drop_duplicates(inplace=True)

# Reset index
df.reset_index(drop=True, inplace=True)

# Display the first few rows of the cleaned dataset
print("Cleaned Dataset:")
print(df.head())
# Out:
# Original Dataset:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Manipulations:
# 1. Removed rows with missing values.
# 2. Converted categorical variables to appropriate data types.
# 3. Converted date columns to datetime format.
# 4. Removed irrelevant columns and duplicates.
#
# Insights:
# 1. Seasonal booking patterns were identified.
# 2. Booking channel distributions were analyzed.
# 3. Guest demographics were examined.
# 4. Cancellation rates and special requests were assessed.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Lead Time vs. Cancellation Status

# %%
# Chart - 1 visualization code
import seaborn as sns
import matplotlib.pyplot as plt

# Chart-1: Relationship between lead time and cancellation status
plt.figure(figsize=(10, 6))
sns.boxplot(x='is_canceled', y='lead_time', data=df)
plt.title('Lead Time vs. Cancellation Status')
plt.xlabel('Cancellation Status')
plt.ylabel('Lead Time (days)')
plt.xticks([0, 1], ['Not Canceled', 'Canceled'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot was chosen to visualize the relationship between lead time and cancellation status because it effectively displays the distribution of lead time for both canceled and non-canceled bookings and allows for easy comparison between the two groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The boxplot reveals that canceled bookings tend to have a longer lead time compared to non-canceled bookings, suggesting that customers may cancel reservations made further in advance more frequently. Additionally, it highlights the presence of outliers in the lead time for both canceled and non-canceled bookings, indicating potential anomalies or unusual booking patterns.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the chart can help create a positive business impact. By understanding that canceled bookings tend to have a longer lead time, hotels can implement strategies to minimize cancellations, such as offering flexible cancellation policies or targeted marketing campaigns to encourage early bookings.
#
# However, one potential negative impact could arise if hotels solely focus on reducing cancellations without considering other factors. For example, if hotels prioritize short-term bookings over long-term ones to minimize cancellations, it may lead to decreased revenue opportunities from guests who prefer to plan their trips in advance. Therefore, a balanced approach that considers both reducing cancellations and maximizing revenue is essential for sustainable growth.Answer Here

# %% [markdown]
# #### Chart - 2 Booking Cancellations by Market Segment

# %%
# Chart - 2 visualization code
import seaborn as sns
import matplotlib.pyplot as plt

# Chart-2: Distribution of booking cancellations across market segments
plt.figure(figsize=(10, 6))
sns.countplot(x='market_segment', hue='is_canceled', data=df)
plt.title('Booking Cancellations by Market Segment')
plt.xlabel('Market Segment')
plt.ylabel('Frequency')
plt.legend(title='Cancellation Status', labels=['Not Canceled', 'Canceled'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a count plot to visualize the distribution of booking cancellations across market segments because it effectively displays the frequency of cancellations within each segment, allowing for easy comparison. This type of chart is suitable for categorical data analysis and provides insights into cancellation patterns across different market segments.Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer HereFrom the chart, we can observe the following insights:
#
# 1. Online Travel Agents (OTA) and Groups segments have relatively higher cancellation rates compared to other segments.
# 2. Direct and Corporate segments have lower cancellation rates, indicating more stable booking behavior within these segments.
# 3. The Transient segment, which includes individual leisure travelers, exhibits a mixed pattern with both high and low cancellation rates across different subcategories.
#
# These insights highlight the varying cancellation behavior across different market segments, which can inform targeted marketing and revenue management strategies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can help create a positive business impact by allowing hotels to tailor their marketing and pricing strategies to different market segments, potentially reducing cancellations and maximizing revenue.
#
# However, if not addressed strategically, the higher cancellation rates in certain segments like OTA and Groups may lead to negative growth by impacting revenue stability and operational efficiency, necessitating targeted efforts to mitigate cancellations within these segments.Answer Here

# %% [markdown]
# #### Chart - 3 Average Daily Rate (ADR) by Room Type

# %%
# Chart - 3 visualization code
import seaborn as sns
import matplotlib.pyplot as plt

# Chart-3: Average Daily Rate (ADR) by Room Type
plt.figure(figsize=(10, 6))
sns.barplot(x='reserved_room_type', y='adr', data=df)
plt.title('Average Daily Rate (ADR) by Room Type')
plt.xlabel('Room Type')
plt.ylabel('Average Daily Rate (ADR)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar plot to visualize the average daily rate (ADR) across different room types because it effectively displays comparisons of numerical values (ADR) between categorical variables (room types), allowing for easy identification of pricing variations and revenue opportunities within each room category.Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, we can observe the following insights:
#
# 1. Suites (room type 'P') have the highest average daily rate (ADR), indicating they may be premium offerings.
# 2. Standard rooms (room type 'A') generally have lower ADR compared to other room types, suggesting they may be more affordable options.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can help create a positive business impact by informing pricing strategies to maximize revenue from premium room types while ensuring competitive pricing for standard rooms, potentially increasing overall revenue.
#
# However, if pricing discrepancies between room types are too significant, it may lead to negative growth by alienating budget-conscious customers or reducing overall occupancy rates, necessitating a balanced approach to pricing to maintain competitiveness and maximize revenue.Answer Here

# %% [markdown]
# #### Chart - 4 Trend of Booking Cancellations Over Time

# %%
# Chart - 4 visualization code
import seaborn as sns
import matplotlib.pyplot as plt

# Extract month from reservation_status_date
df['reservation_month'] = df['reservation_status_date'].dt.month

# Count cancellations by month
cancellation_counts = df[df['is_canceled'] == 1]['reservation_month'].value_counts().sort_index()

# Chart-4: Trend of Booking Cancellations Over Time
plt.figure(figsize=(10, 6))
sns.lineplot(x=cancellation_counts.index, y=cancellation_counts.values, marker='o')
plt.title('Trend of Booking Cancellations Over Time')
plt.xlabel('Month')
plt.ylabel('Number of Cancellations')
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a line plot to visualize the trend of booking cancellations over time because it effectively displays the sequential nature of the data (months) and allows for easy identification of trends or patterns in cancellation behavior over different time periods.Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, we can observe the following insights:
#
# 1. Booking cancellations tend to fluctuate throughout the year, with higher peaks observed in certain months.
# 2. There may be seasonal patterns or trends in cancellation behavior, such as higher cancellations during peak travel seasons or specific events.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can help create a positive business impact by informing strategic decisions to allocate resources and adjust pricing or marketing strategies to mitigate cancellations during peak periods, potentially improving revenue stability and customer satisfaction.
#
# However, if the trend shows consistently high cancellations without actionable mitigation strategies, it may lead to negative growth by impacting revenue and occupancy rates, highlighting the need for proactive measures to address underlying causes of cancellations.

# %% [markdown]
# #### Chart - 5 "Average Number of Special Requests by Cancellation Status."

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Chart-5: Average Number of Special Requests by Cancellation Status
plt.figure(figsize=(10, 6))
sns.barplot(x='is_canceled', y='total_of_special_requests', data=df)
plt.title('Average Number of Special Requests by Cancellation Status')
plt.xlabel('Cancellation Status')
plt.ylabel('Average Number of Special Requests')
plt.xticks([0, 1], ['Not Canceled', 'Canceled'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a bar plot to visualize the average number of special requests by cancellation status because it effectively compares the average values of a numerical variable (total special requests) across two categorical groups (canceled and not canceled), making it easy to discern any significant differences or patterns.

# %% [markdown]
# What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that non-canceled bookings tend to have a higher average number of special requests compared to canceled bookings. This suggests that guests who make special requests might be more committed to their reservations and less likely to cancel.

# %% [markdown]
# #### Chart - 6 Distribution of Booking Cancellations by Room Type.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Chart-6: Distribution of Booking Cancellations by Room Type
plt.figure(figsize=(10, 6))
sns.countplot(x='reserved_room_type', hue='is_canceled', data=df)
plt.title('Distribution of Booking Cancellations by Room Type')
plt.xlabel('Room Type')
plt.ylabel('Frequency')
plt.legend(title='Cancellation Status', labels=['Not Canceled', 'Canceled'])
plt.show()

# %% [markdown]
# 1.Why did you pick the specific chart?

# %% [markdown]
# I chose a count plot to visualize the distribution of booking cancellations by room type because it effectively displays the frequency of cancellations within each category of room type. This type of chart allows for easy comparison of cancellation rates across different room types, helping to identify any disparities or patterns.

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that certain room types, such as type 'A' and 'D', have higher cancellation rates compared to others. Conversely, room types like 'H' and 'L' have relatively lower cancellation rates. This insight can guide hotel management in optimizing room allocation strategies and implementing targeted measures to reduce cancellations for specific room types.

# %% [markdown]
# #### Chart - 7  Trend of Booking Cancellations Over Time

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Extract month from reservation_status_date
df['reservation_month'] = df['reservation_status_date'].dt.month

# Count cancellations by month
cancellation_counts = df[df['is_canceled'] == 1]['reservation_month'].value_counts().sort_index()

# Chart-7: Trend of Booking Cancellations Over Time
plt.figure(figsize=(10, 6))
sns.lineplot(x=cancellation_counts.index, y=cancellation_counts.values, marker='o')
plt.title('Trend of Booking Cancellations Over Time')
plt.xlabel('Month')
plt.ylabel('Number of Cancellations')
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()

# %% [markdown]
# 1.Why did you pick the specific chart?

# %% [markdown]
# I chose a line plot to visualize the trend of booking cancellations over time because it effectively displays the sequential nature of the data (months) and allows for easy identification of trends or patterns in cancellation behavior over different time periods.

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals any seasonal patterns or trends in booking cancellations over the course of the year. For example, if there are peaks in cancellations during certain months, it may indicate periods of high demand or specific events that influence cancellation behavior. Identifying these patterns can help hotels adjust their strategies to mitigate cancellations during peak periods.

# %% [markdown]
# #### Chart - 8 Distribution of Lead Time by Cancellation Status

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Chart-8: Distribution of Lead Time by Cancellation Status
plt.figure(figsize=(10, 6))
sns.violinplot(x='is_canceled', y='lead_time', data=df)
plt.title('Distribution of Lead Time by Cancellation Status')
plt.xlabel('Cancellation Status')
plt.ylabel('Lead Time (days)')
plt.xticks([0, 1], ['Not Canceled', 'Canceled'])
plt.show()

# %% [markdown]
# 1.Why did you pick the specific chart?

# %% [markdown]
# I chose a violin plot to visualize the distribution of lead time by cancellation status because it effectively displays the distribution of a numerical variable (lead time) across two categorical groups (canceled and not canceled). This type of chart allows for a comparison of the distribution shapes, central tendencies, and spread of lead time between the two groups.

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that the distribution of lead time tends to be longer for canceled bookings compared to non-canceled bookings. This suggests that bookings made further in advance may be more likely to be canceled. Additionally, the violin plot highlights the variability in lead time distributions for both canceled and non-canceled bookings, indicating different booking behaviors among guests.

# %% [markdown]
# #### Chart - 9 Distribution of Total Special Requests by Cancellation Status

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Chart-9: Distribution of Total Special Requests by Cancellation Status
plt.figure(figsize=(10, 6))
sns.swarmplot(x='is_canceled', y='total_of_special_requests', data=df)
plt.title('Distribution of Total Special Requests by Cancellation Status')
plt.xlabel('Cancellation Status')
plt.ylabel('Total Special Requests')
plt.xticks([0, 1], ['Not Canceled', 'Canceled'])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 38.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 58.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 1.Why did you pick the specific chart?

# %% [markdown]
# I chose a swarm plot to visualize the distribution of the total number of special requests by cancellation status because it effectively displays individual data points along with their distribution. This type of chart allows for a clear comparison of the distribution of special requests between canceled and non-canceled bookings.

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that bookings with higher numbers of special requests tend to have a lower likelihood of being canceled. This suggests that guests who make more special requests may be more committed to their reservations. Additionally, the swarm plot highlights the variability in the distribution of special requests for both canceled and non-canceled bookings, indicating different guest preferences and behaviors.

# %% [markdown]
# #### Chart - 10 Distribution of Booking Changes by Cancellation Status

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Chart-10: Distribution of Booking Changes by Cancellation Status
plt.figure(figsize=(10, 6))
sns.boxplot(x='is_canceled', y='booking_changes', data=df)
plt.title('Distribution of Booking Changes by Cancellation Status')
plt.xlabel('Cancellation Status')
plt.ylabel('Booking Changes')
plt.xticks([0, 1], ['Not Canceled', 'Canceled'])
plt.show()

# %% [markdown]
# 1.Why did you pick the specific chart?

# %% [markdown]
# I chose a box plot to visualize the distribution of booking changes by cancellation status because it effectively displays the distribution of a numerical variable (booking changes) across two categorical groups (canceled and not canceled). This type of chart allows for a comparison of the central tendency, spread, and variability of booking changes between the two groups.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# I chose a box plot to visualize the distribution of booking changes by cancellation status because it effectively displays the distribution of a numerical variable (booking changes) across two categorical groups (canceled and not canceled). This type of chart allows for a comparison of the central tendency, spread, and variability of booking changes between the two groups.

# %% [markdown]
# #### Chart - 11 Average Daily Rate (ADR) by Cancellation Status and Market Segment

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Chart-11: Average Daily Rate (ADR) by Cancellation Status and Market Segment
plt.figure(figsize=(12, 8))
sns.barplot(x='market_segment', y='adr', hue='is_canceled', data=df)
plt.title('Average Daily Rate (ADR) by Cancellation Status and Market Segment')
plt.xlabel('Market Segment')
plt.ylabel('Average Daily Rate (ADR)')
plt.legend(title='Cancellation Status', labels=['Not Canceled', 'Canceled'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 1.Why did you pick the specific chart?

# %% [markdown]
# I chose a grouped bar plot to visualize the average daily rate (ADR) by cancellation status and market segment because it effectively displays comparisons of numerical values (ADR) across multiple categorical groups (market segments and cancellation status). This type of chart allows for easy identification of ADR differences between canceled and non-canceled bookings within each market segment.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides insights into the relationship between ADR, cancellation status, and market segmentation. It reveals that in most market segments, the ADR for canceled bookings is lower than for non-canceled bookings. This suggests that guests who eventually cancel their bookings may have booked at lower rates compared to those who keep their reservations. Additionally, the chart highlights any disparities in ADR across different market segments, which can inform pricing and revenue management strategies tailored to each segment.

# %% [markdown]
# #### Chart - 12 Distribution of Lead Time by Deposit Type

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Chart-12: Distribution of Lead Time by Deposit Type
plt.figure(figsize=(10, 6))
sns.boxplot(x='deposit_type', y='lead_time', data=df)
plt.title('Distribution of Lead Time by Deposit Type')
plt.xlabel('Deposit Type')
plt.ylabel('Lead Time (days)')
plt.show()

# %% [markdown]
# 1.Why did you pick the specific chart?

# %% [markdown]
# I chose a box plot to visualize the distribution of lead time by deposit type because it effectively displays the distribution of a numerical variable (lead time) across multiple categories (deposit types). This type of chart allows for easy comparison of the central tendency, spread, and variability of lead time between different deposit types.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides insights into the relationship between deposit type and lead time. It reveals that guests who make non-refundable deposits tend to book further in advance (higher lead time) compared to guests who make refundable or no deposits. This suggests that guests who are committed to their reservations are more likely to make non-refundable deposits, potentially influencing revenue management strategies and cancellation policies.

# %% [markdown]
# #### Chart - 13  Distribution of Booking Cancellations by Customer Type

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Chart-13: Distribution of Booking Cancellations by Customer Type
plt.figure(figsize=(10, 6))
sns.countplot(x='customer_type', hue='is_canceled', data=df)
plt.title('Distribution of Booking Cancellations by Customer Type')
plt.xlabel('Customer Type')
plt.ylabel('Frequency')
plt.legend(title='Cancellation Status', labels=['Not Canceled', 'Canceled'])
plt.show()

# %% [markdown]
# 1.Why did you pick the specific chart?

# %% [markdown]
# I chose a count plot to visualize the distribution of booking cancellations by customer type because it effectively displays the frequency of cancellations within each category of customer type. This type of chart allows for easy comparison of cancellation rates across different customer types, helping to identify any disparities or patterns.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides insights into the relationship between customer type and booking cancellations. It reveals that transient guests, who book individually or in small groups, have the highest frequency of cancellations compared to other customer types. This suggests that transient guests may exhibit more flexible booking behavior or be more sensitive to changes in travel plans. Additionally, the chart highlights any differences in cancellation rates across customer types, which can inform targeted marketing and service strategies for different customer segments.

# %% [markdown]
# #### Chart - 14  Correlation Heatmap

# %%
# Correlation Heatmap visualization code
import seaborn as sns
import matplotlib.pyplot as plt

# Select numerical columns for correlation analysis
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Calculate the correlation matrix
correlation_matrix = df[numerical_cols].corr()

# Plot correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a correlation heatmap because it effectively visualizes the pairwise correlations between numerical variables in the dataset. This type of chart allows for a quick and comprehensive understanding of the relationships between variables, highlighting potential patterns or dependencies that may exist.Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the correlation heatmap, we can observe the following insights:
#
# 1. There is a strong positive correlation between variables such as lead time and booking cancellations, indicating that bookings made further in advance are more likely to be canceled.
# 2. There is a negative correlation between variables such as lead time and stays in weekend nights, suggesting that longer lead times may be associated with fewer weekend stays.
# 3. Variables such as average daily rate (ADR) and total of special requests show weak correlations with other numerical variables, indicating that they may be influenced by factors not captured in the dataset.
#
# These insights provide valuable information about the relationships between numerical variables in the dataset, which can inform further analysis and strategic decision-making.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
import seaborn as sns
import matplotlib.pyplot as plt

# Select a subset of relevant numerical columns for the pairplot
pairplot_columns = ['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'adr']

# Generate the pairplot
sns.pairplot(df[pairplot_columns], diag_kind='kde')
plt.suptitle('Pairplot of Selected Numerical Variables', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a pair plot because it allows for a comprehensive visualization of the relationships between pairs of numerical variables in the dataset. This type of chart provides scatter plots to examine the correlation between variables and histograms to visualize the distribution of individual variables, enabling a deeper exploration of the data and potential patterns or trends.Answer Here.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the pair plot, we can observe the following insights:
#
# 1. Some variables, such as lead time and stays in weekend nights, show positive correlations, suggesting that longer lead times may be associated with longer weekend stays.
# 2. Other variables, such as lead time and booking changes, exhibit more scattered relationships, indicating less clear correlations between them.
# 3. The diagonal of the pair plot displays histograms of individual variables, showing their distributions, which can help identify outliers or unusual patterns.
#
# These insights provide valuable information about the relationships between pairs of numerical variables in the dataset, facilitating further analysis and understanding of the data.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve the business objective of optimizing revenue management strategies and enhancing guest satisfaction based on the insights gained from the analysis, I would suggest the following actions:
#
# 1. **Implement Dynamic Pricing**: Utilize the insights on seasonal booking patterns, cancellation rates, and room type ADR to implement dynamic pricing strategies. Adjust pricing based on demand fluctuations, lead time, and booking channel to maximize revenue during peak periods and incentivize longer stays during off-peak times.
#
# 2. **Tailor Marketing Efforts**: Utilize insights on guest demographics and market segments to tailor marketing efforts and promotional campaigns. Target specific customer segments with personalized offers and packages to attract new guests and retain loyal customers.
#
# 3. **Enhance Customer Experience**: Utilize insights on special requests and guest preferences to enhance the overall guest experience. Implement personalized services and amenities based on guest profiles to exceed expectations and foster positive reviews and repeat bookings.
#
# 4. **Optimize Inventory Management**: Utilize insights on booking patterns and occupancy rates to optimize inventory management. Adjust room allocations, pricing tiers, and package offerings to optimize revenue while maintaining high occupancy levels and minimizing cancellations.
#
# By implementing these strategies based on the insights gained from the analysis, the client can effectively optimize revenue management, increase guest satisfaction, and maintain a competitive edge in the hospitality industry.Answer Here.

# %% [markdown]
# # **6.Conclusion**

# %% [markdown]
# In summary, the analysis of the hotel booking dataset has uncovered pivotal insights that can significantly impact the client's business strategy. By delving into seasonal booking trends, guest demographics, and cancellation patterns, the client can tailor their marketing efforts and pricing strategies to maximize revenue and enhance guest satisfaction. Understanding the correlation between lead time and cancellations allows for proactive measures to mitigate cancellations, while insights into the distribution of cancellations across market segments enable targeted marketing campaigns to specific customer segments. Moreover, variations in average daily rates (ADR) among room types provide opportunities for dynamic pricing strategies, ensuring competitive pricing while maximizing revenue potential.
#
# Overall, leveraging these insights to inform strategic decision-making will enable the client to stay ahead in a competitive market landscape. By optimizing revenue management strategies, enhancing guest experiences, and fostering customer loyalty, the client can achieve sustainable growth and success in the hospitality industry. The data-driven approach ensures that decisions are grounded in empirical evidence, empowering the client to adapt to evolving market dynamics and drive positive business outcomes.Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
